# %% [markdown]
# #Introduction
#
# Hi, my name is Krista. I am really new to Python but I have experience working with SQL and Power BI.
# I’m excited to learn Python and understand how it can be used for data analysis and automation.
#
# I’m looking forward to improving my programming skills and learning new tools during this training.

# %%
x=5
y=6
print(x+y)
# Out:
# 11
